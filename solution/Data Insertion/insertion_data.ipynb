# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
# Connessione al database tramite SQLAlchemy
engine = create_engine('postgresql://postgres:pwd@localhost/ium-tweb')

# Lettura del file CSV
df = pd.read_csv('.\\solution\\Datasets Analysis\\csv_files\\updated_clubs.csv')

# Inserimento dei dati nel database
df.to_sql('clubs', engine, if_exists='append', index=False)
# Out:
# 426

# %%
engine = create_engine('postgresql://postgres:pwd@localhost/ium-tweb')

df = pd.read_csv('.\\solution\\Datasets Analysis\\csv_files\\competitions_updated.csv')

df.to_sql('competitions', engine, if_exists='append', index=False)
# Out:
# 43

# %%
engine = create_engine('postgresql://postgres:pwd@localhost/ium-tweb')

df = pd.read_csv('.\\solution\\Datasets Analysis\\csv_files\\players.csv')

df.to_sql('players', engine, if_exists='append', index=False)
# Out:
# 302

# %%
engine = create_engine('postgresql://postgres:pwd@localhost/ium-tweb')

df = pd.read_csv('.\\solution\\Datasets Analysis\\csv_files\\player_valuations.csv')

df.to_sql('player_valuations', engine, if_exists='append', index=False)
# Out:
# 663
